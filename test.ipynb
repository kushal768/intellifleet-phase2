# %% [markdown]
# # Test Notebook: Executing optimizer.py and capacity_optimizer.py (step-by-step)
#
# This notebook runs the raw functions with detailed prints: recursive route generation, PuLP LP formulation output, and step-by-step data transformations.

# %%
import sys
import os
import pandas as pd
from datetime import datetime, timedelta
from pulp import *
import logging

logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
logger = logging.getLogger(__name__)
print('✓ Imports OK - Python', sys.version.split()[0])
# Out:
# ✓ Imports OK - Python 3.10.0

# %%
# ============================================================================
# FUNCTION: haversine() - Great-circle distance calculator
# ============================================================================
print("="*100)
print("FUNCTION: haversine() - Great-circle distance calculator")
print("="*100)

from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """Calculate great-circle distance in kilometers between two points."""
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Earth radius in km
    return c * r

print("\n✓ Function defined successfully")

# TEST 1: Real-world city pairs (multimodal logistics hubs)
print("\n" + "-"*100)
print("TEST 1: Real-world logistics hub distances (multimodal routes)")
print("-"*100)

city_pairs = [
    {'route': 'NYC → Philadelphia', 'mode': 'road/truck', 'lon1': -74.0060, 'lat1': 40.7128, 'lon2': -75.1652, 'lat2': 39.9526},
    {'route': 'Boston → NYC', 'mode': 'road/truck', 'lon1': -71.0589, 'lat1': 42.3601, 'lon2': -74.0060, 'lat2': 40.7128},
    {'route': 'NYC → Washington DC', 'mode': 'road/truck', 'lon1': -74.0060, 'lat1': 40.7128, 'lon2': -77.0369, 'lat2': 38.9072},
    {'route': 'Miami → Atlanta', 'mode': 'air/plane', 'lon1': -80.1918, 'lat1': 25.7617, 'lon2': -84.3880, 'lat2': 33.7490},
    {'route': 'NYC → Miami', 'mode': 'air/plane', 'lon1': -74.0060, 'lat1': 40.7128, 'lon2': -80.1918, 'lat2': 25.7617},
]

print(f"Network: {len(city_pairs)} multimodal routes\n")
for i, pair in enumerate(city_pairs, 1):
    dist = haversine(pair['lon1'], pair['lat1'], pair['lon2'], pair['lat2'])
    route_desc = pair['route']
    mode = pair['mode'].upper()
    print(f"  [{i}] {route_desc:<25} | Mode: {mode:<15} | Distance: {dist:>8.2f} km")

# TEST 2: Verification and edge cases
print("\n" + "-"*100)
print("TEST 2: Edge cases and verification")
print("-"*100)

# Same point (distance should be 0)
dist_same = haversine(-74.0, 40.0, -74.0, 40.0)
print(f"  Same point distance: {dist_same:.6f} km (should be ~0)")
assert dist_same < 0.01

# Equator to pole
dist_pole = haversine(0, 0, 0, 90)
print(f"  Equator to North Pole: {dist_pole:.2f} km (should be ~10007)")
assert 9900 < dist_pole < 10100

print("  ✓ All verification tests passed")

print("\n" + "="*100)
print("✓ HAVERSINE FUNCTION TEST COMPLETED")
print("="*100)

print("✓ haversine function ready for use")
# Out:
# ...
# FUNCTION: haversine() - Great-circle distance calculator
# ...
#
# ✓ Function defined successfully
#
# ----------------------------------------------------------------------------------------------------
# TEST 1: Real-world logistics hub distances (multimodal routes)
# ----------------------------------------------------------------------------------------------------
# Network: 5 multimodal routes
#
#   [1] NYC → Philadelphia        | Mode: ROAD/TRUCK      | Distance:   129.61 km
#   [2] Boston → NYC              | Mode: ROAD/TRUCK      | Distance:   306.11 km
#   [3] NYC → Washington DC       | Mode: ROAD/TRUCK      | Distance:   327.58 km
#   [4] Miami → Atlanta           | Mode: AIR/PLANE       | Distance:   975.88 km
#   [5] NYC → Miami               | Mode: AIR/PLANE       | Distance:  1757.96 km
#
# ----------------------------------------------------------------------------------------------------
# TEST 2: Edge cases and verification
# ...

# %%
VEHICLE_SPECS = {
    'truck': {'speed': 80, 'cost': 0.50},
    'van': {'speed': 90, 'cost': 0.40},
    'car': {'speed': 100, 'cost': 0.30},
    'auto': {'speed': 60, 'cost': 0.20},
    'bike': {'speed': 25, 'cost': 0.10},
    'plane': {'speed': 900, 'cost': 2.00},
}
print('✓ VEHICLE_SPECS loaded')
# Out:
# ✓ VEHICLE_SPECS loaded

# %%
# HAVERSINE: Complete with multimodal tests
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """Calculate great-circle distance in km between two points."""
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    return c * 6371

print("="*100)
print("FUNCTION: haversine()")
print("="*100)

# TEST 1: Road and air multimodal routes
print("\n" + "-"*100)
print("TEST 1: Real-world multimodal logistics routes")
print("-"*100)

routes = [
    ('NYC → PHI', 'truck', -74.0060, 40.7128, -75.1652, 39.9526),
    ('NYC → ATL', 'plane', -74.0060, 40.7128, -84.3880, 33.7490),
    ('MIA → ATL', 'truck', -80.1918, 25.7617, -84.3880, 33.7490),
]

for route, mode, lon1, lat1, lon2, lat2 in routes:
    dist = haversine(lon1, lat1, lon2, lat2)
    print(f"  {route:<15} ({mode:<8}): {dist:>8.2f} km")

# TEST 2: Edge cases
print("\n" + "-"*100)
print("TEST 2: Verification")
print("-"*100)

d1 = haversine(-74, 40, -74, 40)
d2 = haversine(0, 0, 0, 90)
print(f"  Same location: {d1:.2f} km (should be 0)")
print(f"  Equator to pole: {d2:.0f} km (should be ~10007)")
assert d1 < 0.01 and 9900 < d2 < 10100

print("\n✓ HAVERSINE TEST COMPLETE\n")
# Out:
# ...
# FUNCTION: haversine()
# ...
#
# ----------------------------------------------------------------------------------------------------
# TEST 1: Real-world multimodal logistics routes
# ----------------------------------------------------------------------------------------------------
#   NYC → PHI       (truck   ):   129.61 km
#   NYC → ATL       (plane   ):  1200.32 km
#   MIA → ATL       (truck   ):   975.88 km
#
# ----------------------------------------------------------------------------------------------------
# TEST 2: Verification
# ----------------------------------------------------------------------------------------------------
#   Same location: 0.00 km (should be 0)
#   Equator to pole: 10008 km (should be ~10007)
#
# ✓ HAVERSINE TEST COMPLETE

# %%
# ============================================================================
# FUNCTION: enumerate_paths() - List all possible routes
# ============================================================================
print("="*100)
print("FUNCTION: enumerate_paths()")
print("="*100)

def enumerate_paths(nodes, edges, start, end, max_depth=10):
    """Recursively enumerate simple paths from start to end."""
    paths = []
    def dfs(current, path, depth):
        if depth > max_depth:
            return
        if current == end:
            paths.append(list(path))
            return
        for u, v in edges.keys():
            if u == current and v not in path:
                path.append(v)
                dfs(v, path, depth+1)
                path.pop()
    dfs(start, [start], 0)
    return paths

print("\n✓ Function defined successfully")

# TEST 1: Simple 4-node network (road routes)
print("\n" + "-"*100)
print("TEST 1: Road-only network (4 nodes)")
print("-"*100)

nodes_test1 = {'A': (0,0), 'B': (1,1), 'C': (2,0), 'D': (3,1)}
edges_test1 = {
    ('A','B'): {'mode': 'truck'},
    ('B','C'): {'mode': 'truck'},
    ('A','C'): {'mode': 'truck'},
    ('C','D'): {'mode': 'truck'},
    ('B','D'): {'mode': 'truck'}
}

print(f"Nodes: {list(nodes_test1.keys())}")
print(f"Edges: {len(edges_test1)} possible routes")
paths1 = enumerate_paths(nodes_test1, edges_test1, 'A', 'D')
print(f"✓ Found {len(paths1)} paths from A to D:")
for i, p in enumerate(paths1, 1):
    path_str = ' → '.join(p)
    print(f"  [{i}] {path_str}")

# TEST 2: Multimodal network (road + air routes)
print("\n" + "-"*100)
print("TEST 2: Multimodal network (road + air) (5 cities)")
print("-"*100)

nodes_test2 = {
    'NYC': (40.7128, -74.0060),
    'PHI': (39.9526, -75.1652),
    'BOS': (42.3601, -71.0589),
    'ATL': (33.7490, -84.3880),
    'MIA': (25.7617, -80.1918)
}
edges_test2 = {
    # Road routes
    ('NYC','PHI'): {'mode': 'truck', 'distance': 150},
    ('PHI','BOS'): {'mode': 'truck', 'distance': 400},
    ('NYC','ATL'): {'mode': 'truck', 'distance': 1060},
    # Air routes
    ('NYC','MIA'): {'mode': 'plane', 'distance': 1280},
    ('BOS','ATL'): {'mode': 'plane', 'distance': 1320},
    ('PHI','ATL'): {'mode': 'plane', 'distance': 850},
    ('ATL','MIA'): {'mode': 'truck', 'distance': 660}
}

print(f"Cities: {list(nodes_test2.keys())}")
print(f"Routes: {len(edges_test2)} (mixed road/air)")
paths2 = enumerate_paths(nodes_test2, edges_test2, 'NYC', 'MIA')
print(f"✓ Found {len(paths2)} paths from NYC to MIA:")
for i, p in enumerate(paths2, 1):
    path_str = ' → '.join(p)
    print(f"  [{i}] {path_str}")

print("\n" + "="*100)
print("✓ ENUMERATE_PATHS TEST COMPLETE")
print("="*100)
# Out:
# ...
# FUNCTION: enumerate_paths()
# ...
#
# ✓ Function defined successfully
#
# ----------------------------------------------------------------------------------------------------
# TEST 1: Road-only network (4 nodes)
# ----------------------------------------------------------------------------------------------------
# Nodes: ['A', 'B', 'C', 'D']
# Edges: 5 possible routes
# ✓ Found 3 paths from A to D:
#   [1] A → B → C → D
#   [2] A → B → D
#   [3] A → C → D
#
# ----------------------------------------------------------------------------------------------------
# TEST 2: Multimodal network (road + air) (5 cities)
# ----------------------------------------------------------------------------------------------------
# Cities: ['NYC', 'PHI', 'BOS', 'ATL', 'MIA']
# Routes: 7 (mixed road/air)
# ✓ Found 4 paths from NYC to MIA:
#   [1] NYC → PHI → BOS → ATL → MIA
#   [2] NYC → PHI → ATL → MIA
#   [3] NYC → ATL → MIA
#   [4] NYC → MIA
#
# ...
# ✓ ENUMERATE_PATHS TEST COMPLETE
# ...

# %%
def optimize(nodes, edges, start, end, objective='cost', via=None, lp_filename='model.lp', solver_msg=True):
    """Build LP problem, print full formulation, write LP file, enumerate paths, and solve with CBC.
    Also prints selection of edges and solver output.
    """
    print('\n' + '='*60)
    print('[OPTIMIZE] Input Analysis')
    print('='*60)
    print(f'  start: {start}, end: {end}')
    print(f'  objective: {objective}, via: {via}')
    print(f'  Nodes ({len(nodes)}):')
    for node, coords in nodes.items():
        print(f'    - {node}: {coords}')
    print(f'  Edges ({len(edges)}):')
    for edge_key, edge_data in edges.items():
        print(f'    - {edge_key}: {edge_data}')

    # Show enumerated potential routes via recursion (for transparency)
    print('\n' + '='*60)
    print('[OPTIMIZE] Step 1: Route Enumeration (DFS Recursion)')
    print('='*60)
    paths = enumerate_paths(nodes, edges, start, end, max_depth=10)
    print(f'\nFound {len(paths)} possible paths')

    print('\n' + '='*60)
    print('[OPTIMIZE] Step 2: Build LP Model')
    print('='*60)
    model = LpProblem('Logistics_Optimization', LpMinimize)
    print('  → Created LpProblem instance')
    
    print('  → Creating binary decision variables for each edge')
    x = LpVariable.dicts('x', edges.keys(), cat='Binary')
    print(f'    Created {len(x)} binary variables: {list(x.keys())}')

    # Objective
    print('\n  → Setting objective function')
    if objective in ('time', 'fastest'):
        print(f'    Minimizing TIME')
        model += lpSum(x[e] * edges[e].get('time', 0) for e in edges), 'Minimize_Time'
    elif objective == 'distance':
        print(f'    Minimizing DISTANCE')
        model += lpSum(x[e] * edges[e].get('distance', 0) for e in edges), 'Minimize_Distance'
    else:
        print(f'    Minimizing COST (fuel)')
        model += lpSum(x[e] * edges[e].get('fuel', 0) for e in edges), 'Minimize_Cost'
    print('    ✓ Objective expression set')

    # Flow constraints
    print('\n  → Adding flow conservation constraints')
    for n_idx, n in enumerate(nodes):
        inflow = lpSum(x[(i, j)] for (i, j) in edges if j == n)
        outflow = lpSum(x[(i, j)] for (i, j) in edges if i == n)
        if n == start:
            model += outflow - inflow == 1, f'flow_start_{n}'
            print(f'    Constraint {n_idx+1}/{len(nodes)} (START/{n}): outflow - inflow = 1')
        elif n == end:
            model += inflow - outflow == 1, f'flow_end_{n}'
            print(f'    Constraint {n_idx+1}/{len(nodes)} (END/{n}): inflow - outflow = 1')
        else:
            model += inflow == outflow, f'flow_int_{n}'
            print(f'    Constraint {n_idx+1}/{len(nodes)} (INTERMEDIATE/{n}): inflow = outflow')

    if via:
        print(f'\n  → Adding VIA constraint(s) for node(s): {via}')
        if isinstance(via, list):
            for v in via:
                model += lpSum(x[(i, j)] for (i, j) in edges if j == v) == 1, f'via_{v}'
                print(f'    Node {v} must have exactly 1 incoming edge')
        else:
            model += lpSum(x[(i, j)] for (i, j) in edges if j == via) == 1, f'via_{via}'
            print(f'    Node {via} must have exactly 1 incoming edge')

    # Print LP formulation
    print('\n' + '='*60)
    print('[OPTIMIZE] Step 3: Write LP File')
    print('='*60)
    try:
        model.writeLP(lp_filename)
        print(f'  ✓ LP written to {lp_filename}')
        with open(lp_filename, 'r') as f:
            lp_text = f.read()
        print(f'  LP File size: {len(lp_text)} chars')
        print('\n  [LP FILE CONTENT - first 1500 chars]:')
        print('  ' + '\n  '.join(lp_text[:1500].split('\n')))
        if len(lp_text) > 1500:
            print(f'  ... ({len(lp_text)-1500} more chars)')
    except Exception as e:
        print(f'  ✗ Could not write/read LP file: {e}')

    print('\n' + '='*60)
    print('[OPTIMIZE] Step 4: Solve with CBC')
    print('='*60)
    solver = PULP_CBC_CMD(msg=1) if solver_msg else PULP_CBC_CMD(msg=0)
    result = model.solve(solver)
    print(f'  Solver result code: {result}')
    print(f'  Model status: {model.status} (1=optimal, 0=not solved, -1=infeasible, -2=unbounded)')
    if model.status != 1:
        print('  ⚠ Warning: optimal solution not found')
    print(f'  Objective value: {model.objective.value()}')

    print('\n' + '='*60)
    print('[OPTIMIZE] Step 5: Extract Solution')
    print('='*60)
    selected = []
    for e_idx, e in enumerate(edges):
        val = x[e].varValue
        print(f'  Variable {e_idx+1}/{len(edges)}: x{e} = {val}', end='')
        if val == 1:
            selected.append(edges[e])
            print(' ✓ SELECTED')
            print(f'    → Edge data: {edges[e]}')
        else:
            print(' ✗ not selected')
    
    print(f'\n  Total selected segments: {len(selected)}')
    return selected

print('✓ optimize defined')

# ============================================================================
# TEST 5: optimize with larger dummy graph (US Cities)
# ============================================================================
print('\n' + '#'*70)
print('# TEST 5: optimize Function with Full LP Formulation')
print('#'*70)

nodes_big = {
    'NYC': (40.7128, -74.0060),
    'Philadelphia': (39.9526, -75.1652),
    'Washington': (38.9072, -77.0369),
    'Atlanta': (33.7490, -84.3880)
}
edges_big = {
    ('NYC','Philadelphia'):{'from':'NYC','to':'Philadelphia','distance':95,'time':1.8,'fuel':47.5,'mode':'truck'},
    ('Philadelphia','Washington'):{'from':'Philadelphia','to':'Washington','distance':140,'time':2.5,'fuel':70.0,'mode':'truck'},
    ('Washington','Atlanta'):{'from':'Washington','to':'Atlanta','distance':640,'time':10.5,'fuel':320.0,'mode':'truck'},
    ('NYC','Washington'):{'from':'NYC','to':'Washington','distance':230,'time':3.8,'fuel':115.0,'mode':'truck'},
    ('Philadelphia','Atlanta'):{'from':'Philadelphia','to':'Atlanta','distance':780,'time':12.5,'fuel':390.0,'mode':'truck'}
}

print(f'\nInput: Find optimal route from NYC to Atlanta')
print(f'  Nodes: {list(nodes_big.keys())}')
print(f'  Edges: {len(edges_big)} possible routes')
print(f'  Objective: Minimize Cost')

selected = optimize(nodes_big, edges_big, 'NYC', 'Atlanta', objective='cost', lp_filename='test_model.lp', solver_msg=True)

print('\n✓ Test 5 complete - Selected route:')
summary_final = get_route_summary(selected)
print('\nFinal Summary:')
for key, val in summary_final.items():
    if key == 'fuel':
        print(f'  {key}: ${val:.2f}')
    elif key == 'time':
        print(f'  {key}: {val:.1f} hours')
    else:
        print(f'  {key}: {val} km')
# Out:
# ✓ optimize defined
#
# ######################################################################
# # TEST 5: optimize Function with Full LP Formulation
# ######################################################################
#
# Input: Find optimal route from NYC to Atlanta
#   Nodes: ['NYC', 'Philadelphia', 'Washington', 'Atlanta']
#   Edges: 5 possible routes
#   Objective: Minimize Cost
#
# ...
# [OPTIMIZE] Input Analysis
# ...
#   start: NYC, end: Atlanta
#   objective: cost, via: None
#   Nodes (4):
#     - NYC: (40.7128, -74.006)
#     - Philadelphia: (39.9526, -75.1652)
#     - Washington: (38.9072, -77.0369)
#     - Atlanta: (33.749, -84.388)
#   Edges (5):
#     - ('NYC', 'Philadelphia'): {'from': 'NYC', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8, 'fuel': 47.5, 'mode': 'truck'}
#     - ('Philadelphia', 'Washington'): {'from': 'Philadelphia', 'to': 'Washington', 'distance': 140, 'time': 2.5, 'fuel': 70.0, 'mode': 'truck'}
# ...

# %%
def get_route_summary(route):
    print('\n' + '='*60)
    print('[GET_ROUTE_SUMMARY] Processing route')
    print('='*60)
    
    # Line: Check if route is empty
    if not route:
        print('  ⚠ Route is empty or None')
        return {}
    
    print(f'  Route has {len(route)} segments')
    
    # Line: Initialize totals
    totals = {'distance': 0, 'time': 0, 'fuel': 0}
    print('  → Initialized totals: distance=0, time=0, fuel=0')
    
    # Line: Iterate through each segment
    print('\n  Processing each segment:')
    for i, seg in enumerate(route, 1):
        print(f'\n  Segment {i}/{len(route)}:')
        print(f'    Data: {seg}')
        
        # Line: Extract distance
        dist = seg.get('distance', 0)
        print(f'    → distance: {dist} km')
        totals['distance'] += dist
        print(f'       Cumulative distance: {totals["distance"]} km')
        
        # Line: Extract time
        time_val = seg.get('time', 0)
        print(f'    → time: {time_val} hours')
        totals['time'] += time_val
        print(f'       Cumulative time: {totals["time"]} hours')
        
        # Line: Extract fuel
        fuel_val = seg.get('fuel', 0)
        print(f'    → fuel cost: ${fuel_val}')
        totals['fuel'] += fuel_val
        print(f'       Cumulative fuel cost: ${totals["fuel"]}')
    
    # Line: Return final totals
    print('\n  Final Totals:')
    print(f'    Distance: {totals["distance"]} km')
    print(f'    Time: {totals["time"]} hours')
    print(f'    Fuel Cost: ${totals["fuel"]:.2f}')
    return totals

print('✓ get_route_summary defined')

# ============================================================================
# TEST 2: get_route_summary with dummy route
# ============================================================================
print('\n' + '#'*70)
print('# TEST 2: get_route_summary Function')
print('#'*70)

dummy_route = [
    {'from': 'NYC', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8, 'fuel': 47.5},
    {'from': 'Philadelphia', 'to': 'Washington', 'distance': 140, 'time': 2.5, 'fuel': 70.0}
]

print(f'\nInput: Route with {len(dummy_route)} segments')
for i, seg in enumerate(dummy_route, 1):
    print(f'  Segment {i}: {seg}')

summary = get_route_summary(dummy_route)

print(f'\n✓ Test 2 complete')
print(f'  Summary: {summary}')
# Out:
# ✓ get_route_summary defined
#
# ######################################################################
# # TEST 2: get_route_summary Function
# ######################################################################
#
# Input: Route with 2 segments
#   Segment 1: {'from': 'NYC', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8, 'fuel': 47.5}
#   Segment 2: {'from': 'Philadelphia', 'to': 'Washington', 'distance': 140, 'time': 2.5, 'fuel': 70.0}
#
# ...
# [GET_ROUTE_SUMMARY] Processing route
# ...
#   Route has 2 segments
#   → Initialized totals: distance=0, time=0, fuel=0
#
#   Processing each segment:
#
#   Segment 1/2:
#     Data: {'from': 'NYC', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8, 'fuel': 47.5}
#     → distance: 95 km
#        Cumulative distance: 95 km
#     → time: 1.8 hours
#        Cumulative time: 1.8 hours
#     → fuel cost: $47.5
#        Cumulative fuel cost: $47.5
#
#   Segment 2/2:
# ...

# %%
def prepare_vehicles_df(vehicles_df):
    print('\n' + '='*60)
    print('[PREPARE_VEHICLES_DF] Processing vehicle data')
    print('='*60)
    
    # Line: Show input
    print(f'\n  Input DataFrame ({len(vehicles_df)} rows):')
    print(vehicles_df.to_string())
    
    # Line: Create copy
    print('\n  → Creating copy of input dataframe')
    df = vehicles_df.copy()
    print('     ✓ Copy created')
    
    # Line: Process warehouse names to base_city
    print('\n  → Converting WarehouseName to base_city (lowercase, stripped)')
    df['base_city'] = df['WarehouseName'].str.lower().str.strip()
    for i, city in enumerate(df['base_city'], 1):
        print(f'     Row {i}: "{df.iloc[i-1]["WarehouseName"]}" → "{city}"')
    
    # Line: Process vehicle types
    print('\n  → Converting VehicleType to vehicle_type (lowercase, stripped)')
    df['vehicle_type'] = df['VehicleType'].str.lower().str.strip()
    for i, vtype in enumerate(df['vehicle_type'], 1):
        print(f'     Row {i}: "{df.iloc[i-1]["VehicleType"]}" → "{vtype}"')
    
    # Line: Convert capacity to numeric
    print('\n  → Converting VehicleCapacity to capacity_kg (numeric)')
    df['capacity_kg'] = pd.to_numeric(df['VehicleCapacity'], errors='coerce')
    for i, cap in enumerate(df['capacity_kg'], 1):
        print(f'     Row {i}: {cap} kg')
    
    # Line: Process departure times
    print('\n  → Extracting DepartureTime')
    df['departure_time'] = df['DepartureTime'].str.strip()
    for i, dept in enumerate(df['departure_time'], 1):
        print(f'     Row {i}: {dept}')

    # Line: Group by city and count
    print('\n  → Assigning vehicle numbers by city (vehicle_id_num)')
    df['vehicle_id_num'] = df.groupby('base_city').cumcount() + 1
    print('     Groupby city counts:')
    for i, row in df.iterrows():
        print(f'     Row {i+1}: city={row["base_city"]}, vehicle_id_num={row["vehicle_id_num"]}')
    
    # Line: Format vehicle ID
    print('\n  → Formatting vehicle_id: CITY_CODE-TYPE_CODE-NUMBER')
    def format_vid(row):
        city_code = row['base_city'][:3].upper()
        type_code = row['vehicle_type'][:3].upper()
        vid = f"{city_code}-{type_code}-{row['vehicle_id_num']:02d}"
        return vid
    df['vehicle_id'] = df.apply(format_vid, axis=1)
    for i, row in df.iterrows():
        print(f'     Row {i+1}: {row["vehicle_id"]} (from {row["base_city"]} {row["vehicle_type"]})')
    
    # Line: Map speed from VEHICLE_SPECS
    print('\n  → Mapping speed_kmph from VEHICLE_SPECS')
    df['speed_kmph'] = df['vehicle_type'].map(lambda x: VEHICLE_SPECS.get(x, {}).get('speed', 60))
    for i, row in df.iterrows():
        spec = VEHICLE_SPECS.get(row['vehicle_type'], {})
        print(f'     Row {i+1}: {row["vehicle_type"]} → {row["speed_kmph"]} kmph (spec: {spec})')
    
    # Line: Map cost from VEHICLE_SPECS
    print('\n  → Mapping cost_per_km from VEHICLE_SPECS')
    df['cost_per_km'] = df['vehicle_type'].map(lambda x: VEHICLE_SPECS.get(x, {}).get('cost', 0.5))
    for i, row in df.iterrows():
        spec = VEHICLE_SPECS.get(row['vehicle_type'], {})
        print(f'     Row {i+1}: {row["vehicle_type"]} → ${row["cost_per_km"]}/km (spec: {spec})')
    
    # Line: Select relevant columns
    print('\n  → Selecting relevant columns for output')
    output_cols = ['vehicle_id','base_city','vehicle_type','capacity_kg','speed_kmph','cost_per_km','departure_time']
    print(f'     Columns: {output_cols}')
    
    print('\n  Output DataFrame:')
    result = df[output_cols]
    print(result.to_string())
    
    return result

print('✓ prepare_vehicles_df defined')

# ============================================================================
# TEST 3: prepare_vehicles_df with dummy vehicle data
# ============================================================================
print('\n' + '#'*70)
print('# TEST 3: prepare_vehicles_df Function')
print('#'*70)

vehicles_raw = pd.DataFrame({
    'WarehouseName': ['New York', 'New York', 'Philadelphia', 'Philadelphia'],
    'VehicleType': ['Truck', 'Van', 'Truck', 'Bike'],
    'VehicleCapacity': [5000, 2000, 5000, 100],
    'DepartureTime': ['08:00', '09:00', '07:00', '10:30']
})

print(f'\nInput: {len(vehicles_raw)} vehicles from 2 cities')
print('Raw DataFrame:')
print(vehicles_raw)

vehicles_prepared = prepare_vehicles_df(vehicles_raw)

print(f'\n✓ Test 3 complete - Prepared {len(vehicles_prepared)} vehicles')
# Out:
# ✓ prepare_vehicles_df defined
#
# ######################################################################
# # TEST 3: prepare_vehicles_df Function
# ######################################################################
#
# Input: 4 vehicles from 2 cities
# Raw DataFrame:
#   WarehouseName VehicleType  VehicleCapacity DepartureTime
# 0      New York       Truck             5000         08:00
# 1      New York         Van             2000         09:00
# 2  Philadelphia       Truck             5000         07:00
# 3  Philadelphia        Bike              100         10:30
#
# ...
# [PREPARE_VEHICLES_DF] Processing vehicle data
# ...
#
#   Input DataFrame (4 rows):
#   WarehouseName VehicleType  VehicleCapacity DepartureTime
# 0      New York       Truck             5000         08:00
# 1      New York         Van             2000         09:00
# 2  Philadelphia       Truck             5000         07:00
# 3  Philadelphia        Bike              100         10:30
#
# ...

# %%
def assign_vehicles_for_leg(vehicles_df, leg, total_goods, objective='cost'):
    print('\n' + '='*60)
    print('[ASSIGN_VEHICLES_FOR_LEG] Vehicle Assignment for Leg')
    print('='*60)
    
    # Line: Show input parameters
    print('\n  Input Parameters:')
    print(f'    leg: {leg}')
    print(f'    total_goods: {total_goods} kg')
    print(f'    objective: {objective} (time or cost)')
    
    # Line: Extract source city
    print('\n  → Extracting source city from leg["from"]')
    src = leg['from'].lower()
    print(f'    Source city: {src}')
    
    # Line: Filter available vehicles
    print('\n  → Filtering vehicles available at source city')
    available = vehicles_df[vehicles_df['base_city'].str.lower()==src].copy()
    print(f'    Found {len(available)} available vehicles:')
    if len(available) > 0:
        print(available.to_string())
    else:
        print('    ⚠ No vehicles available')
    
    # Line: Check if any vehicles available
    if available.empty:
        print('\n  ✗ RESULT: No vehicles available at this location')
        return None
    
    # Line: Create LP model
    print('\n' + '-'*60)
    print('  LP Model Setup:')
    print('-'*60)
    model = LpProblem('Vehicle_Assignment', LpMinimize)
    print('  → Created LP model: Vehicle_Assignment')
    
    # Line: Create decision variables
    print('  → Creating binary decision variables for each vehicle')
    x = LpVariable.dicts('v', available.index, cat='Binary')
    print(f'    Variables: {list(x.keys())}')
    
    # Line: Set objective
    print('\n  → Setting objective function')
    if objective=='time':
        print(f'    Minimizing travel TIME')
        model += lpSum(x[i] * (leg['distance']/available.loc[i,'speed_kmph']) for i in available.index)
        for i in available.index:
            speed = available.loc[i,'speed_kmph']
            travel_time = leg['distance']/speed
            print(f'      Variable v[{i}]: {leg["distance"]} km / {speed} kmph = {travel_time:.2f} hours')
    else:
        print(f'    Minimizing travel COST')
        model += lpSum(x[i] * available.loc[i,'cost_per_km'] * leg['distance'] for i in available.index)
        for i in available.index:
            cost_km = available.loc[i,'cost_per_km']
            total_cost = cost_km * leg['distance']
            print(f'      Variable v[{i}]: ${cost_km}/km × {leg["distance"]} km = ${total_cost:.2f}')
    
    # Line: Add capacity constraint
    print(f'\n  → Adding capacity constraint: sum(capacity × selected) >= {total_goods} kg')
    capacity_expr = lpSum(x[i]*available.loc[i,'capacity_kg'] for i in available.index)
    model += capacity_expr >= total_goods
    print(f'    Available capacities:')
    for i in available.index:
        cap = available.loc[i,'capacity_kg']
        vid = available.loc[i,'vehicle_id']
        print(f'      v[{i}] ({vid}): {cap} kg')
    print(f'    Constraint: capacity_sum >= {total_goods} kg')
    
    # Line: Write LP file
    print('\n  → Writing LP file: assign_model.lp')
    model.writeLP('assign_model.lp')
    print('    ✓ File written')
    try:
        lp_content = open('assign_model.lp').read()
        print(f'    LP file size: {len(lp_content)} chars')
        print('    [First 800 chars]:')
        print('    ' + '\n    '.join(lp_content[:800].split('\n')))
    except Exception as e:
        print(f'    Could not read file: {e}')
    
    # Line: Solve
    print('\n' + '-'*60)
    print('  Solving:')
    print('-'*60)
    res = model.solve(PULP_CBC_CMD(msg=1))
    print(f'  Solve result code: {res}')
    print(f'  Model status: {model.status}')
    
    # Line: Extract solution
    print('\n' + '-'*60)
    print('  Solution Extraction:')
    print('-'*60)
    assigned = []
    remain = total_goods
    print(f'  Remaining goods to assign: {remain} kg')
    
    for i in available.index:
        var_val = x[i].varValue
        vid = available.loc[i,'vehicle_id']
        cap = available.loc[i,'capacity_kg']
        cost_per_km = available.loc[i,'cost_per_km']
        speed = available.loc[i,'speed_kmph']
        
        print(f'\n  Vehicle {i}: {vid}')
        print(f'    Variable value (selected): {var_val}')
        print(f'    Capacity: {cap} kg')
        print(f'    Remaining to assign: {remain} kg')
        
        if var_val==1 and remain>0:
            load = min(cap, remain)
            depart = available.loc[i,'departure_time'] if pd.notna(available.loc[i,'departure_time']) else '08:00'
            travel_time = leg['distance']/speed
            travel_cost = cost_per_km * leg['distance']
            
            print(f'    ✓ ASSIGNED!')
            print(f'      Load: {load} kg (capacity: {cap} kg)')
            print(f'      Departure: {depart}')
            print(f'      Travel time: {leg["distance"]}km / {speed}kmph = {travel_time:.2f} hours')
            print(f'      Travel cost: ${travel_cost:.2f}')
            
            assigned.append({
                'vehicle_id':vid,
                'load_kg':load,
                'departure':depart,
                'travel_time':travel_time
            })
            remain -= load
            print(f'      Remaining after: {remain} kg')
        else:
            if var_val != 1:
                print(f'    ✗ NOT selected by optimizer')
            else:
                print(f'    ✗ Already assigned to other legs')
    
    # Line: Create result
    print('\n' + '='*60)
    print('  FINAL ASSIGNMENT RESULT:')
    print('='*60)
    result = {
        'from': leg['from'],
        'to': leg['to'],
        'distance': leg['distance'],
        'vehicles': assigned,
        'total_load': total_goods - remain
    }
    print(f'  From: {result["from"]}')
    print(f'  To: {result["to"]}')
    print(f'  Distance: {result["distance"]} km')
    print(f'  Assigned vehicles ({len(assigned)}):')
    for v in assigned:
        print(f'    - {v}')
    print(f'  Total load assigned: {result["total_load"]} kg')
    print(f'  Remaining unassigned: {remain} kg')
    
    return result

print('✓ assign_vehicles_for_leg defined')

# ============================================================================
# TEST 4: assign_vehicles_for_leg with prepared vehicles
# ============================================================================
print('\n' + '#'*70)
print('# TEST 4: assign_vehicles_for_leg Function')
print('#'*70)

leg_1 = {'from': 'New York', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8}
total_goods_1 = 4500  # kg

print(f'\nInput: Assigning vehicles for leg NY → Philadelphia')
print(f'  Distance: {leg_1["distance"]} km')
print(f'  Goods to transport: {total_goods_1} kg')
print(f'  Objective: cost')

assignment_1 = assign_vehicles_for_leg(vehicles_prepared, leg_1, total_goods_1, objective='cost')
print(f'\n✓ Test 4 complete - Assignment result:')
print(assignment_1)
# Out:
# ✓ assign_vehicles_for_leg defined
#
# ######################################################################
# # TEST 4: assign_vehicles_for_leg Function
# ######################################################################
#
# Input: Assigning vehicles for leg NY → Philadelphia
#   Distance: 95 km
#   Goods to transport: 4500 kg
#   Objective: cost
#
# ...
# [ASSIGN_VEHICLES_FOR_LEG] Vehicle Assignment for Leg
# ...
#
#   Input Parameters:
#     leg: {'from': 'New York', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8}
#     total_goods: 4500 kg
#     objective: cost (time or cost)
#
#   → Extracting source city from leg["from"]
#     Source city: new york
#
#   → Filtering vehicles available at source city
#     Found 2 available vehicles:
#    vehicle_id base_city vehicle_type  capacity_kg  speed_kmph  cost_per_km departure_time
# 0  NEW-TRU-01  new york        truck         5000          80          0.5          08:00
# ...

# %%
# ============================================================================
# MULTILEG ROUTE TEST: Weight/Capacity Assignment Across Multiple Legs
# ============================================================================
print("\n" + "="*100)
print("MULTILEG ROUTE TEST: Weight Distribution & Vehicle Assignment")
print("="*100)

# Create a multileg route: NYC → PHI → Washington → Atlanta
multileg_route = [
    {'leg_num': 1, 'from': 'New York', 'to': 'Philadelphia', 'distance': 95, 'time': 1.8},
    {'leg_num': 2, 'from': 'Philadelphia', 'to': 'Washington', 'distance': 140, 'time': 2.5},
    {'leg_num': 3, 'from': 'Washington', 'to': 'Atlanta', 'distance': 640, 'time': 10.5}
]

total_cargo_weight = 15000  # kg total cargo to distribute

print(f"\nRoute: NYC → Philadelphia → Washington → Atlanta")
print(f"Total cargo: {total_cargo_weight} kg")
print(f"Number of legs: {len(multileg_route)}")

# Create vehicles at each warehouse
print("\n" + "-"*100)
print("Creating multileg warehouse network with vehicles at each location")
print("-"*100)

vehicles_multileg = pd.DataFrame({
    'WarehouseName': [
        'New York', 'New York', 'New York',
        'Philadelphia', 'Philadelphia',
        'Washington', 'Washington',
        'Atlanta', 'Atlanta'
    ],
    'VehicleType': [
        'Truck', 'Van', 'Truck',
        'Truck', 'Van',
        'Truck', 'Truck',
        'Truck', 'Van'
    ],
    'VehicleCapacity': [
        6000, 2000, 5000,
        5000, 1500,
        6000, 4500,
        6000, 2000
    ],
    'DepartureTime': [
        '08:00', '09:00', '10:00',
        '08:30', '10:00',
        '09:00', '11:00',
        '08:00', '10:00'
    ]
})

print(f"Created {len(vehicles_multileg)} vehicles across 4 warehouses:")
print(f"  • New York: 3 vehicles (Truck 6000kg, Van 2000kg, Truck 5000kg)")
print(f"  • Philadelphia: 2 vehicles (Truck 5000kg, Van 1500kg)")
print(f"  • Washington: 2 vehicles (Truck 6000kg, Truck 4500kg)")
print(f"  • Atlanta: 2 vehicles (Truck 6000kg, Van 2000kg)")

# Prepare the vehicles
print("\nPreparing vehicles dataframe...")
vehicles_multileg_prep = prepare_vehicles_df(vehicles_multileg)

print("\n" + "="*100)
print("TEST 1: MULTILEG CAPACITY ASSIGNMENT - Cost-Optimized")
print("="*100)

all_assignments = []
remaining_cargo = total_cargo_weight

print(f"\nObjective: Minimize cost while distributing {remaining_cargo} kg across multiple legs\n")

for leg in multileg_route:
    print(f"\n{'─'*100}")
    print(f"LEG {leg['leg_num']}: {leg['from']} → {leg['to']} ({leg['distance']}km)")
    print(f"{'─'*100}")
    print(f"  Remaining cargo to assign: {remaining_cargo} kg")
    
    # Assign vehicles for this leg
    assignment = assign_vehicles_for_leg(
        vehicles_multileg_prep, 
        leg, 
        remaining_cargo,
        objective='cost'
    )
    
    if assignment and 'vehicles' in assignment and len(assignment['vehicles']) > 0:
        all_assignments.append(assignment)
        assigned_weight = sum(v['load_kg'] for v in assignment['vehicles'])
        remaining_cargo -= assigned_weight
        
        print(f"\n  ✓ Assignment result:")
        print(f"    Weight assigned on leg: {assigned_weight} kg")
        print(f"    Remaining for next legs: {remaining_cargo} kg")
        print(f"    Vehicles used: {len(assignment['vehicles'])}")
        for v in assignment['vehicles']:
            print(f"      • {v['vehicle_id']}: {v['load_kg']}kg")

# Print cost-optimized route summary
print(f"\n\n" + "="*100)
print("MULTILEG ROUTE SUMMARY - COST-OPTIMIZED ASSIGNMENT")
print("="*100)

if all_assignments:
    total_assigned = 0
    total_distance_summary = 0
    total_cost_summary = 0

    for i, assignment in enumerate(all_assignments, 1):
        distance = assignment['distance']
        total_distance_summary += distance
        weight_assigned = sum(v['load_kg'] for v in assignment['vehicles'])
        total_assigned += weight_assigned
        
        # Calculate cost for this leg
        leg_cost = 0
        for v in assignment['vehicles']:
            vehicle_row = vehicles_multileg_prep[vehicles_multileg_prep['vehicle_id']==v['vehicle_id']]
            if not vehicle_row.empty:
                cost_per_km = vehicle_row.iloc[0]['cost_per_km']
                leg_cost += cost_per_km * distance
        
        total_cost_summary += leg_cost
        
        capacity_used = weight_assigned
        print(f"\nLeg {i}: {assignment['from']} → {assignment['to']}")
        print(f"  Distance: {distance} km")
        print(f"  Weight carried: {weight_assigned} kg")
        print(f"  Capacity utilization: {capacity_used} kg")
        print(f"  Cost: ${leg_cost:.2f}")
        print(f"  Vehicles ({len(assignment['vehicles'])}):")
        for v in assignment['vehicles']:
            print(f"    • {v['vehicle_id']}: {v['load_kg']}kg load, depart {v['departure']}, travel {v['travel_time']:.2f}h")

    print(f"\n{'='*100}")
    print(f"COST-OPTIMIZED TOTALS:")
    print(f"  Total distance: {total_distance_summary} km")
    print(f"  Total weight carried: {total_assigned} kg / {total_cargo_weight} kg ({100*total_assigned/total_cargo_weight:.1f}% capacity utilization)")
    print(f"  Total transportation cost: ${total_cost_summary:.2f}")
    print(f"  Unassigned cargo: {total_cargo_weight - total_assigned} kg")
else:
    print("No assignments completed")

# ============================================================================
# TEST 2: Time-Optimized Assignment
# ============================================================================
print(f"\n\n" + "="*100)
print("TEST 2: MULTILEG CAPACITY ASSIGNMENT - Time-Optimized")
print("="*100)

all_assignments_time = []
remaining_cargo_time = total_cargo_weight

print(f"\nObjective: Minimize travel time while distributing {remaining_cargo_time} kg across multiple legs\n")

for leg in multileg_route:
    print(f"\n{'─'*100}")
    print(f"LEG {leg['leg_num']}: {leg['from']} → {leg['to']} ({leg['distance']}km)")
    print(f"{'─'*100}")
    print(f"  Remaining cargo to assign: {remaining_cargo_time} kg")
    
    # Assign vehicles (time objective)
    assignment = assign_vehicles_for_leg(
        vehicles_multileg_prep, 
        leg, 
        remaining_cargo_time,
        objective='time'
    )
    
    if assignment and 'vehicles' in assignment and len(assignment['vehicles']) > 0:
        all_assignments_time.append(assignment)
        assigned_weight = sum(v['load_kg'] for v in assignment['vehicles'])
        remaining_cargo_time -= assigned_weight
        
        print(f"\n  ✓ Assignment result:")
        print(f"    Weight assigned on leg: {assigned_weight} kg")
        print(f"    Remaining for next legs: {remaining_cargo_time} kg")
        print(f"    Vehicles used: {len(assignment['vehicles'])}")

# Print time-optimized route summary
print(f"\n\n" + "="*100)
print("MULTILEG ROUTE SUMMARY - TIME-OPTIMIZED ASSIGNMENT")
print("="*100)

if all_assignments_time:
    total_assigned_time = 0
    total_distance_time = 0
    total_time_travel = 0

    for i, assignment in enumerate(all_assignments_time, 1):
        distance = assignment['distance']
        total_distance_time += distance
        weight_assigned = sum(v['load_kg'] for v in assignment['vehicles'])
        total_assigned_time += weight_assigned
        
        # Travel time (max due to parallel execution)
        leg_travel_time = max([v['travel_time'] for v in assignment['vehicles']], default=0)
        total_time_travel += leg_travel_time
        
        print(f"\nLeg {i}: {assignment['from']} → {assignment['to']}")
        print(f"  Distance: {distance} km")
        print(f"  Weight carried: {weight_assigned} kg")
        print(f"  Travel time: {leg_travel_time:.2f} hours (parallel vehicles)")
        print(f"  Vehicles ({len(assignment['vehicles'])}):")
        for v in assignment['vehicles']:
            print(f"    • {v['vehicle_id']}: {v['load_kg']}kg load, {v['travel_time']:.2f}h")

    print(f"\n{'='*100}")
    print(f"TIME-OPTIMIZED TOTALS:")
    print(f"  Total distance: {total_distance_time} km")
    print(f"  Total weight carried: {total_assigned_time} kg / {total_cargo_weight} kg ({100*total_assigned_time/total_cargo_weight:.1f}% capacity utilization)")
    print(f"  Total travel time: {total_time_travel:.2f} hours (parallel execution)")
    print(f"  Unassigned cargo: {total_cargo_weight - total_assigned_time} kg")

# ============================================================================
# COMPARISON
# ============================================================================
print(f"\n\n" + "="*100)
print("COMPARISON: Cost-Optimized vs Time-Optimized Multileg Routes")
print("="*100)

if all_assignments and all_assignments_time:
    print(f"\n{'Cost-Optimized Route':<40} {'Time-Optimized Route':<40}")
    print(f"{'-'*40} {'-'*40}")
    print(f"{'Distance: '+str(total_distance_summary)+' km':<40} {'Distance: '+str(total_distance_time)+' km':<40}")
    print(f"{'Cost: $'+str(f'{total_cost_summary:.2f}'):<40} {'Time: '+str(f'{total_time_travel:.2f}')+' hours':<40}")
    print(f"{'Coverage: '+str(f'{100*total_assigned/total_cargo_weight:.1f}')+'%':<40} {'Coverage: '+str(f'{100*total_assigned_time/total_cargo_weight:.1f}')+'%':<40}")

print(f"\n✓ MULTILEG ROUTE CAPACITY ASSIGNMENT TESTS COMPLETE")
print("="*100)
# Out:
# ...
# MULTILEG ROUTE TEST: Weight Distribution & Vehicle Assignment
# ...
#
# Route: NYC → Philadelphia → Washington → Atlanta
# Total cargo: 15000 kg
# Number of legs: 3
#
# ----------------------------------------------------------------------------------------------------
# Creating multileg warehouse network with vehicles at each location
# ----------------------------------------------------------------------------------------------------
# Created 9 vehicles across 4 warehouses:
#   • New York: 3 vehicles (Truck 6000kg, Van 2000kg, Truck 5000kg)
#   • Philadelphia: 2 vehicles (Truck 5000kg, Van 1500kg)
#   • Washington: 2 vehicles (Truck 6000kg, Truck 4500kg)
#   • Atlanta: 2 vehicles (Truck 6000kg, Van 2000kg)
#
# Preparing vehicles dataframe...
#
# ...
# [PREPARE_VEHICLES_DF] Processing vehicle data
# ...
#
#   Input DataFrame (9 rows):
#   WarehouseName VehicleType  VehicleCapacity DepartureTime
# 0      New York       Truck             6000         08:00
# ...

# %% [markdown]
# # DisruptionManager Functions: Step-by-Step Testing
#
# Each function from disruption_manager.py is included in its own cell below, followed by a test cell with dummy data and print statements for step-by-step validation.

# %%
# Utility: haversine function
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """Calculate great-circle distance in kilometers between two points."""
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Earth radius in km
    return c * r

# %%
# DisruptionManager __init__
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional
import json

class DisruptionManager:
    def __init__(self, warehouses_df: pd.DataFrame, road_routes_df: pd.DataFrame, vehicles_df: pd.DataFrame = None):
        print('Initializing DisruptionManager...')
        print('warehouses_df:')
        print(warehouses_df)
        print('road_routes_df:')
        print(road_routes_df)
        print('vehicles_df:')
        print(vehicles_df)
        self.warehouses_df = warehouses_df
        self.road_routes_df = road_routes_df
        self.vehicles_df = vehicles_df

# %%
# Test for __init__
warehouses_df = pd.DataFrame([
    {'City': 'Alpha', 'Name': 'Alpha Warehouse', 'Inventory': 120, 'ReorderLevel': 20},
    {'City': 'Beta', 'Name': 'Beta Warehouse', 'Inventory': 80, 'ReorderLevel': 10},
    {'City': 'Gamma', 'Name': 'Gamma Warehouse', 'Inventory': 50, 'ReorderLevel': 5},
])
road_routes_df = pd.DataFrame([
    {'source_city': 'Alpha', 'destination_city': 'Beta', 'lat_src': 10.0, 'lon_src': 20.0, 'lat_dst': 11.0, 'lon_dst': 21.0},
    {'source_city': 'Beta', 'destination_city': 'Gamma', 'lat_src': 11.0, 'lon_src': 21.0, 'lat_dst': 12.0, 'lon_dst': 22.0},
    {'source_city': 'Alpha', 'destination_city': 'Gamma', 'lat_src': 10.0, 'lon_src': 20.0, 'lat_dst': 12.0, 'lon_dst': 22.0},
])
vehicles_df = pd.DataFrame([
    {'WarehouseName': 'Alpha', 'VehicleType': 'Truck', 'VehicleCapacity': 100, 'DepartureTime': '08:00'},
    {'WarehouseName': 'Beta', 'VehicleType': 'Truck', 'VehicleCapacity': 60, 'DepartureTime': '09:00'},
    {'WarehouseName': 'Gamma', 'VehicleType': 'Truck', 'VehicleCapacity': 40, 'DepartureTime': '10:00'},
])
manager = DisruptionManager(warehouses_df, road_routes_df, vehicles_df)
print('DisruptionManager initialized:')
print('warehouses_df:')
print(manager.warehouses_df)
print('road_routes_df:')
print(manager.road_routes_df)
print('vehicles_df:')
print(manager.vehicles_df)
# Out:
# Initializing DisruptionManager...
# warehouses_df:
#     City             Name  Inventory  ReorderLevel
# 0  Alpha  Alpha Warehouse        120            20
# 1   Beta   Beta Warehouse         80            10
# 2  Gamma  Gamma Warehouse         50             5
# road_routes_df:
#   source_city destination_city  lat_src  lon_src  lat_dst  lon_dst
# 0       Alpha             Beta     10.0     20.0     11.0     21.0
# 1        Beta            Gamma     11.0     21.0     12.0     22.0
# 2       Alpha            Gamma     10.0     20.0     12.0     22.0
# vehicles_df:
#   WarehouseName VehicleType  VehicleCapacity DepartureTime
# 0         Alpha       Truck              100         08:00
# 1          Beta       Truck               60         09:00
# 2         Gamma       Truck               40         10:00
# DisruptionManager initialized:
# warehouses_df:
#     City             Name  Inventory  ReorderLevel
# 0  Alpha  Alpha Warehouse        120            20
# ...

# %%
# DisruptionManager.find_nearest_warehouses

def find_nearest_warehouses(self, origin_lat, origin_lon, demand_weight, exclude_cities=None, max_results=None):
    print(f'Called find_nearest_warehouses with origin=({origin_lat},{origin_lon}), demand_weight={demand_weight}, exclude_cities={exclude_cities}, max_results={max_results}')
    if exclude_cities is None:
        exclude_cities = []
    city_coords = {}
    for _, route in self.road_routes_df.iterrows():
        src_city = str(route.get('source_city', '')).lower().strip()
        dst_city = str(route.get('destination_city', '')).lower().strip()
        if src_city and src_city not in city_coords:
            city_coords[src_city] = (route.get('lat_src', 0), route.get('lon_src', 0))
        if dst_city and dst_city not in city_coords:
            city_coords[dst_city] = (route.get('lat_dst', 0), route.get('lon_dst', 0))
    print('city_coords:', city_coords)
    available_warehouses = []
    for _, warehouse in self.warehouses_df.iterrows():
        city = warehouse.get('City', '').strip().lower()
        if city in [c.lower() for c in exclude_cities]:
            continue
        inventory = warehouse.get('Inventory', 0)
        reorder_level = warehouse.get('ReorderLevel', 0)
        if inventory > reorder_level:
            coords = city_coords.get(city, (0, 0))
            warehouse_lat, warehouse_lon = coords
            available_to_use = inventory - reorder_level
            wh = {
                'city': str(city),
                'Name': str(warehouse.get('Name', city)),
                'inventory': int(inventory),
                'reorder_level': int(reorder_level),
                'available_quantity': int(available_to_use),
                'lat': float(warehouse_lat),
                'lon': float(warehouse_lon)
            }
            print('Available warehouse:', wh)
            available_warehouses.append(wh)
    for warehouse in available_warehouses:
        distance = haversine(origin_lat, origin_lon, warehouse['lat'], warehouse['lon'])
        warehouse['distance_km'] = float(distance)
        print(f"Distance to {warehouse['city']}: {warehouse['distance_km']} km")
    available_warehouses.sort(key=lambda x: x['distance_km'])
    print('Sorted available_warehouses:', available_warehouses)
    return available_warehouses if max_results is None else available_warehouses[:max_results]

DisruptionManager.find_nearest_warehouses = find_nearest_warehouses

# %%
# Test for find_nearest_warehouses
origin_lat, origin_lon = 10.5, 20.5
demand_weight = 30
nearest = manager.find_nearest_warehouses(origin_lat, origin_lon, demand_weight)
print('Nearest warehouses to (10.5, 20.5) for demand 30kg:')
for wh in nearest:
    print(wh)
# Out:
# Called find_nearest_warehouses with origin=(10.5,20.5), demand_weight=30, exclude_cities=None, max_results=None
# city_coords: {'alpha': (10.0, 20.0), 'beta': (11.0, 21.0), 'gamma': (12.0, 22.0)}
# Available warehouse: {'city': 'alpha', 'Name': 'Alpha Warehouse', 'inventory': 120, 'reorder_level': 20, 'available_quantity': 100, 'lat': 10.0, 'lon': 20.0}
# Available warehouse: {'city': 'beta', 'Name': 'Beta Warehouse', 'inventory': 80, 'reorder_level': 10, 'available_quantity': 70, 'lat': 11.0, 'lon': 21.0}
# Available warehouse: {'city': 'gamma', 'Name': 'Gamma Warehouse', 'inventory': 50, 'reorder_level': 5, 'available_quantity': 45, 'lat': 12.0, 'lon': 22.0}
# Distance to alpha: 76.23534321325995 km
# Distance to beta: 76.11918579417292 km
# Distance to gamma: 227.9973286990307 km
# ...

# %%
# DisruptionManager.estimate_delivery_time

def estimate_delivery_time(self, source_city, destination_city, repair_duration_hours=5, disruption_time="22:00", required_delivery_time="10:00"):
    print(f'Called estimate_delivery_time: {source_city} -> {destination_city}, repair_duration_hours={repair_duration_hours}, disruption_time={disruption_time}, required_delivery_time={required_delivery_time}')
    route_match = self.road_routes_df[
        (self.road_routes_df['source_city'].str.lower() == source_city.lower()) &
        (self.road_routes_df['destination_city'].str.lower() == destination_city.lower())
    ]
    distance_km = None
    if not route_match.empty:
        route = route_match.iloc[0]
        print('Direct route found:', route.to_dict())
        distance_km = haversine(route['lat_src'], route['lon_src'], route['lat_dst'], route['lon_dst'])
    else:
        print('No direct route found, building city_coords...')
        city_coords = {}
        for _, route in self.road_routes_df.iterrows():
            src_city = str(route.get('source_city', '')).lower().strip()
            dst_city = str(route.get('destination_city', '')).lower().strip()
            if src_city and src_city not in city_coords:
                city_coords[src_city] = (route.get('lat_src', 0), route.get('lon_src', 0))
            if dst_city and dst_city not in city_coords:
                city_coords[dst_city] = (route.get('lat_dst', 0), route.get('lon_dst', 0))
        print('city_coords:', city_coords)
        src_city_lower = source_city.lower()
        dst_city_lower = destination_city.lower()
        if src_city_lower in city_coords and dst_city_lower in city_coords:
            src_lat, src_lon = city_coords[src_city_lower]
            dst_lat, dst_lon = city_coords[dst_city_lower]
            distance_km = haversine(src_lat, src_lon, dst_lat, dst_lon)
            print(f'Estimated distance using coords: {distance_km}')
        else:
            print('No coordinates found for cities.')
            return {'feasible': False, 'error': f'No route or coordinates found from {source_city} to {destination_city}', 'estimated_delivery_time': None, 'meets_requirement': False}
    try:
        disruption_hour, disruption_min = map(int, disruption_time.split(':'))
        disruption_dt = datetime.strptime(f"{disruption_hour:02d}:{disruption_min:02d}", "%H:%M")
        repair_completion = disruption_dt + timedelta(hours=repair_duration_hours)
        travel_hours = distance_km / 60
        estimated_arrival = repair_completion + timedelta(hours=travel_hours)
        if estimated_arrival.day > disruption_dt.day or estimated_arrival.hour < disruption_dt.hour:
            estimated_arrival_str = f"Next day {estimated_arrival.strftime('%H:%M')}"
            arrival_day_offset = 1
        else:
            estimated_arrival_str = estimated_arrival.strftime("%H:%M")
            arrival_day_offset = 0
        req_hour, req_min = map(int, required_delivery_time.split(':'))
        req_dt_today = datetime.strptime(f"{req_hour:02d}:{req_min:02d}", "%H:%M")
        if arrival_day_offset > 0:
            meets_requirement = False
            time_delta = (24 - disruption_hour + req_hour) + (estimated_arrival.hour - req_hour) + (estimated_arrival.minute - req_min) / 60
        else:
            meets_requirement = estimated_arrival >= req_dt_today
            time_delta = (estimated_arrival - req_dt_today).total_seconds() / 3600
        result = {
            'feasible': True,
            'distance_km': float(round(distance_km, 2)),
            'travel_hours': float(round(travel_hours, 2)),
            'repair_hours': int(repair_duration_hours),
            'disruption_time': str(disruption_time),
            'repair_completion_time': str(repair_completion.strftime("%H:%M")),
            'estimated_delivery_time': str(estimated_arrival_str),
            'required_delivery_time': str(required_delivery_time),
            'meets_requirement': bool(meets_requirement),
            'time_delta_hours': float(round(time_delta, 2))
        }
        print('estimate_delivery_time result:', result)
        return result
    except Exception as e:
        print('Error in estimate_delivery_time:', e)
        return {'feasible': False, 'error': f'Error estimating delivery: {str(e)}', 'estimated_delivery_time': None, 'meets_requirement': False}

DisruptionManager.estimate_delivery_time = estimate_delivery_time

# %%
# Test for estimate_delivery_time
result = manager.estimate_delivery_time('Alpha', 'Beta', repair_duration_hours=2, disruption_time='08:00', required_delivery_time='12:00')
print('Estimate delivery Alpha → Beta:', result)
result2 = manager.estimate_delivery_time('Alpha', 'Gamma', repair_duration_hours=3, disruption_time='09:00', required_delivery_time='18:00')
print('Estimate delivery Alpha → Gamma:', result2)
# Out:
# Called estimate_delivery_time: Alpha -> Beta, repair_duration_hours=2, disruption_time=08:00, required_delivery_time=12:00
# Direct route found: {'source_city': 'Alpha', 'destination_city': 'Beta', 'lat_src': 10.0, 'lon_src': 20.0, 'lat_dst': 11.0, 'lon_dst': 21.0}
# estimate_delivery_time result: {'feasible': True, 'distance_km': 152.35, 'travel_hours': 2.54, 'repair_hours': 2, 'disruption_time': '08:00', 'repair_completion_time': '10:00', 'estimated_delivery_time': '12:32', 'required_delivery_time': '12:00', 'meets_requirement': True, 'time_delta_hours': 0.54}
# Estimate delivery Alpha → Beta: {'feasible': True, 'distance_km': 152.35, 'travel_hours': 2.54, 'repair_hours': 2, 'disruption_time': '08:00', 'repair_completion_time': '10:00', 'estimated_delivery_time': '12:32', 'required_delivery_time': '12:00', 'meets_requirement': True, 'time_delta_hours': 0.54}
# ...

# %%
# DisruptionManager.find_warehouse_combinations

def find_warehouse_combinations(self, source_warehouse, destination_city, demand_weight, disruption_time, required_delivery_time, repair_duration_hours, available_warehouses, max_combinations=3):
    print(f'Called find_warehouse_combinations: source_warehouse={source_warehouse}, destination_city={destination_city}, demand_weight={demand_weight}')
    combinations = []
    for i in range(len(available_warehouses)):
        for j in range(i + 1, len(available_warehouses)):
            wh1 = available_warehouses[i]
            wh2 = available_warehouses[j]
            if wh1['available_quantity'] >= demand_weight or wh2['available_quantity'] >= demand_weight:
                continue
            combined_available = (wh1['available_quantity'] + wh2['available_quantity'])
            if combined_available >= demand_weight:
                print(f'Checking pair: {wh1["city"]}, {wh2["city"]}')
                delivery_analysis_1 = self.estimate_delivery_time(source_warehouse, wh1['city'], repair_duration_hours, disruption_time, required_delivery_time)
                delivery_analysis_2 = self.estimate_delivery_time(source_warehouse, wh2['city'], repair_duration_hours, disruption_time, required_delivery_time)
                meets_req_1 = delivery_analysis_1.get('meets_requirement', False)
                meets_req_2 = delivery_analysis_2.get('meets_requirement', False)
                meets_requirement = meets_req_1 and meets_req_2
                time_1 = delivery_analysis_1.get('estimated_delivery_time', '')
                time_2 = delivery_analysis_2.get('estimated_delivery_time', '')
                if not time_1:
                    time_1 = ''
                if not time_2:
                    time_2 = ''
                if 'Next day' in str(time_1) and 'Next day' not in str(time_2):
                    bottleneck_time = time_1
                elif 'Next day' in str(time_2) and 'Next day' not in str(time_1):
                    bottleneck_time = time_2
                elif 'Next day' in str(time_1) and 'Next day' in str(time_2):
                    bottleneck_time = time_1 if str(time_1) > str(time_2) else time_2
                else:
                    bottleneck_time = time_1 if (str(time_1) or '00:00') > (str(time_2) or '00:00') else time_2
                split1 = min(int(wh1['available_quantity']), demand_weight)
                split2 = demand_weight - split1
                combo = {
                    'warehouse1_city': str(wh1['city']),
                    'warehouse1_name': str(wh1.get('Name', wh1['city'])),
                    'warehouse1_delivery': split1,
                    'warehouse1_capacity': int(wh1['available_quantity']),
                    'warehouse2_city': str(wh2['city']),
                    'warehouse2_name': str(wh2.get('Name', wh2['city'])),
                    'warehouse2_delivery': split2,
                    'warehouse2_capacity': int(wh2['available_quantity']),
                    'combined_delivery_time': str(bottleneck_time),
                    'meets_requirement': bool(meets_requirement),
                    'distance_sum': float(round(wh1['distance_km'] + wh2['distance_km'], 2))
                }
                print('Combination:', combo)
                combinations.append(combo)
    combinations.sort(key=lambda x: (not x['meets_requirement'], x['distance_sum']))
    print('Sorted combinations:', combinations)
    return combinations[:max_combinations]

DisruptionManager.find_warehouse_combinations = find_warehouse_combinations

# %%
# Test for find_warehouse_combinations
avail_wh = manager.find_nearest_warehouses(10.5, 20.5, 70)
combinations = manager.find_warehouse_combinations('Alpha', 'Gamma', 70, '08:00', '18:00', 2, avail_wh)
print('Warehouse combinations to fulfill 70kg from Alpha to Gamma:')
for combo in combinations:
    print(combo)
# Out:
# Called find_nearest_warehouses with origin=(10.5,20.5), demand_weight=70, exclude_cities=None, max_results=None
# city_coords: {'alpha': (10.0, 20.0), 'beta': (11.0, 21.0), 'gamma': (12.0, 22.0)}
# Available warehouse: {'city': 'alpha', 'Name': 'Alpha Warehouse', 'inventory': 120, 'reorder_level': 20, 'available_quantity': 100, 'lat': 10.0, 'lon': 20.0}
# Available warehouse: {'city': 'beta', 'Name': 'Beta Warehouse', 'inventory': 80, 'reorder_level': 10, 'available_quantity': 70, 'lat': 11.0, 'lon': 21.0}
# Available warehouse: {'city': 'gamma', 'Name': 'Gamma Warehouse', 'inventory': 50, 'reorder_level': 5, 'available_quantity': 45, 'lat': 12.0, 'lon': 22.0}
# Distance to alpha: 76.23534321325995 km
# Distance to beta: 76.11918579417292 km
# Distance to gamma: 227.9973286990307 km
# ...

# %%
# DisruptionManager._assign_transport (dummy for test)
def _assign_transport(self, source_city, dest_city, load_kg):
    print(f'Called _assign_transport: {source_city} -> {dest_city}, load_kg={load_kg}')
    # Dummy implementation for notebook testing
    result = {'vehicles': [{'vehicle_id': 'TRK-001', 'departure': '08:00', 'arrival': '12:00'}]}
    print('Returning:', result)
    return result
DisruptionManager._assign_transport = _assign_transport

# %%
# Test for _assign_transport
assign_result = manager._assign_transport('Alpha', 'Beta', 50)
print('Assign transport Alpha → Beta for 50kg:')
print(assign_result)

# %%
# DisruptionManager._get_vehicle_departure_from_warehouse
def _get_vehicle_departure_from_warehouse(self, warehouse_city, destination_city, load_kg):
    print(f'Called _get_vehicle_departure_from_warehouse: {warehouse_city} -> {destination_city}, load_kg={load_kg}')
    transport = self._assign_transport(warehouse_city, destination_city, load_kg)
    print('Transport result:', transport)
    if transport and transport.get('vehicles'):
        v = transport['vehicles'][0]
        result = {'vehicle_id': v.get('vehicle_id', 'N/A'), 'departure_time': v.get('departure', 'N/A'), 'arrival_time': v.get('arrival', 'N/A')}
        print('Returning:', result)
        return result
    print('Returning empty dict')
    return {}
DisruptionManager._get_vehicle_departure_from_warehouse = _get_vehicle_departure_from_warehouse

# %%
# DisruptionManager._get_bottleneck_time
def _get_bottleneck_time(self, warehouse_city, destination_city, load_kg):
    print(f'Called _get_bottleneck_time: {warehouse_city} -> {destination_city}, load_kg={load_kg}')
    transport = self._assign_transport(warehouse_city, destination_city, load_kg)
    print('Transport result:', transport)
    if transport and transport.get('vehicles'):
        times = [v.get('arrival', 0) for v in transport['vehicles']]
        print('Arrival times:', times)
        if times:
            bottleneck = max(times)
            print('Bottleneck time:', bottleneck)
            return bottleneck
    print('Returning 0')
    return 0
DisruptionManager._get_bottleneck_time = _get_bottleneck_time

# %%
# DisruptionManager.handle_disruption
def handle_disruption(self, disruption_info):
    print('Handling disruption with info:', disruption_info)
    # Example: disruption_info = {'type': 'road_closure', 'location': 'CityA', 'start_time': 10, 'end_time': 20}
    # This is a stub for demonstration
    print('Disruption type:', disruption_info.get('type'))
    print('Disruption location:', disruption_info.get('location'))
    print('Disruption start_time:', disruption_info.get('start_time'))
    print('Disruption end_time:', disruption_info.get('end_time'))
    # Simulate some logic
    result = {'status': 'handled', 'details': disruption_info}
    print('Returning:', result)
    return result
DisruptionManager.handle_disruption = handle_disruption

# %%
# Test for _get_bottleneck_time
# Provide warehouse_city, destination_city, and load_kg as arguments
bottleneck = manager._get_bottleneck_time('Alpha', 'Beta', 50)
print('Bottleneck (latest) arrival time:', bottleneck)
# Out:
# Called _get_bottleneck_time: Alpha -> Beta, load_kg=50
# Called _assign_transport: Alpha -> Beta, load_kg=50
# Returning: {'vehicles': [{'vehicle_id': 'TRK-001', 'departure': '08:00', 'arrival': '12:00'}]}
# Transport result: {'vehicles': [{'vehicle_id': 'TRK-001', 'departure': '08:00', 'arrival': '12:00'}]}
# Arrival times: ['12:00']
# Bottleneck time: 12:00
# Bottleneck (latest) arrival time: 12:00

# %%
# DisruptionManager.handle_disruption (simplified for test)
def handle_disruption(self, source_warehouse, destination_city, demand_weight, disruption_time="22:00", required_delivery_time="10:00", repair_duration_hours=5, max_alternative_warehouses=3, disruption_location=None):
    print('handle_disruption called')
    print('Estimate original route:')
    orig = self.estimate_delivery_time(source_warehouse, destination_city, repair_duration_hours, disruption_time, required_delivery_time)
    print(orig)
    print('Find nearest warehouses:')
    whs = self.find_nearest_warehouses(0, 0, demand_weight)
    print(whs)
    return {'original_route': orig, 'nearest_warehouses': whs}
DisruptionManager.handle_disruption = handle_disruption

# %%
# Test for handle_disruption
full_result = manager.handle_disruption(
    source_warehouse='Alpha',
    destination_city='Gamma',
    demand_weight=70,
    disruption_time='08:00',
    required_delivery_time='18:00',
    repair_duration_hours=2,
    max_alternative_warehouses=2
)
print('handle_disruption result:')
import json
print(json.dumps(full_result, indent=2))

# %%
# analyze_disruption_scenario utility function
def analyze_disruption_scenario(warehouses_df, road_routes_df, source_warehouse, destination_city, demand_weight, disruption_time="22:00", required_delivery_time="10:00", repair_duration_hours=5, disruption_location=None, vehicles_df=None):
    print('Calling analyze_disruption_scenario...')
    print('warehouses_df:')
    print(warehouses_df)
    print('road_routes_df:')
    print(road_routes_df)
    print(f'source_warehouse: {source_warehouse}, destination_city: {destination_city}, demand_weight: {demand_weight}')
    print(f'disruption_time: {disruption_time}, required_delivery_time: {required_delivery_time}, repair_duration_hours: {repair_duration_hours}')
    manager = DisruptionManager(warehouses_df, road_routes_df, vehicles_df=vehicles_df)
    result = manager.handle_disruption(source_warehouse, destination_city, demand_weight, disruption_time, required_delivery_time, repair_duration_hours, disruption_location=disruption_location)
    print('Result from handle_disruption:')
    print(result)
    return result

# %%
# Test DisruptionManager on bigger dummy data
import pandas as pd

# Create a larger set of warehouses
dummy_warehouses = pd.DataFrame([
    {'WarehouseName': f'City{i}', 'Latitude': 10 + i, 'Longitude': 20 + i} for i in range(10)
])

# Create a larger set of road routes (fully connected for simplicity)
dummy_routes = []
for i in range(10):
    for j in range(10):
        if i != j:
            dummy_routes.append({
                'source_city': f'City{i}',
                'destination_city': f'City{j}',
                'lat_src': 10 + i,
                'lon_src': 20 + i,
                'lat_dst': 10 + j,
                'lon_dst': 20 + j,
                'distance': abs(i-j)*10 + 50
            })
dummy_road_routes = pd.DataFrame(dummy_routes)

# Create a larger set of vehicles
vehicle_types = ['Truck', 'Van', 'Bike']
dummy_vehicles = pd.DataFrame([
    {
        'WarehouseName': f'City{i}',
        'VehicleType': vehicle_types[i % 3],
        'VehicleCapacity': 100 + 50 * (i % 3),
        'DepartureTime': f'{8 + (i % 3)}:00'
    }
    for i in range(10) for _ in range(3)
])

# Initialize DisruptionManager with big dummy data
big_manager = DisruptionManager(dummy_warehouses, dummy_road_routes, dummy_vehicles)
print('Initialized DisruptionManager with big dummy data.')
print('Warehouses:')
print(dummy_warehouses.head())
print('Road Routes:')
print(dummy_road_routes.head())
print('Vehicles:')
print(dummy_vehicles.head())

# Test a function: find_nearest_warehouses
nearest = big_manager.find_nearest_warehouses('City0', 3)
print('Nearest warehouses to City0:', nearest)
# Out:
# --- Testing analyze_disruption_scenario ---
# Calling analyze_disruption_scenario...
# warehouses_df:
#     City             Name  Inventory  ReorderLevel
# 0  Alpha  Alpha Warehouse        120            20
# 1   Beta   Beta Warehouse         80            10
# 2  Gamma  Gamma Warehouse         50             5
# road_routes_df:
#   source_city destination_city  lat_src  lon_src  lat_dst  lon_dst
# 0       Alpha             Beta     10.0     20.0     11.0     21.0
# 1        Beta            Gamma     11.0     21.0     12.0     22.0
# 2       Alpha            Gamma     10.0     20.0     12.0     22.0
# source_warehouse: Alpha, destination_city: Gamma, demand_weight: 70
# disruption_time: 08:00, required_delivery_time: 18:00, repair_duration_hours: 2
# Initializing DisruptionManager...
# warehouses_df:
#     City             Name  Inventory  ReorderLevel
# 0  Alpha  Alpha Warehouse        120            20
# 1   Beta   Beta Warehouse         80            10
# ...
